# %% [markdown]
# In this notebook I will be using a Simple Linear Regression Model
# - This model will determie the correlation between and employees years of experience and their salary

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Loading in the Dataset

# %%
dataset = pd.read_csv(r'C:\Users\Erica\Desktop\Traditional Machine Learning\Code\Machine Learning A-Z\Part 2 - Regression\Section 4 - Simple Linear Regression\Python\Salary_Data.csv')
X = dataset.iloc[:, :-1].values # Selects all columns except the last column of the dataset
y = dataset.iloc[:, -1].values # Selects only the last column of the dataset

# %%
print(X)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
print(y)
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %% [markdown]
# Train/Test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %% [markdown]
# Training the Simple Linear Regression Model
# - Using a library for a clear refined example of a Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
# From the scikit learn library we are importing the Linear Regression Class
# This model is an instance of the Linear Regression Class

regressor = LinearRegression()
# This creates a simple linear regression model

regressor.fit(X_train, y_train)
# This will train the model on the Independent Variables (X_train) and the Dependent Variables (y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Predicting the Test set Results

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# Visualizing the Training set Results

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train))
plt.title("Salary vs Experience (Training set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# Visualizing the Test set Results

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_test, regressor.predict(X_test))
plt.title("Salary vs Experience (Test set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')
